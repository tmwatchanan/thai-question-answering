# %%
import os
import glob
import re
from pythainlp.tokenize import word_tokenize, isthai
from pythainlp.tag import pos_tag
from pythainlp.corpus import stopwords
import heapq
from gensim.models import Word2Vec
from pythainlp.word_vector import thai2vec

thai_stopwords = stopwords.words('thai')

examples_path = 'Test1\\'
question_list_filename = examples_path + 'question_list.txt'
# expected_answer_list_filename = examples_path + 'expected_ans.txt'
sources_dir_name = examples_path + 'Sources\\'

numbers = re.compile(r'(\d+)')
def numerical_sort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

document_list = []
for source_filename in sorted(glob.glob(os.path.join(sources_dir_name, '*.txt')), key=numerical_sort):
    with open(source_filename , encoding='utf-8') as f:
        document = []
        for line in f:
            document.append(line.rstrip('\n'))
        document_list.append(document)

question_list = []
with open(question_list_filename, encoding='utf-8') as f:
    for line in f:
        list_of_each_line = [n for n in line.strip().split('::')]
        for t_idx, token in enumerate(list_of_each_line):
            list_of_each_line[t_idx] = list_of_each_line[t_idx].replace(u'\ufeff', '')
        question_list.append(list_of_each_line)
        
print("Questions = ", question_list)

# expected_answer_list = []
# with open(expected_answer_list_filename, encoding='utf-8') as f:
#     for line in f:
#         list_of_each_line = [n for n in line.strip().split('::')]
#         for t_idx, token in enumerate(list_of_each_line):
#             list_of_each_line[t_idx] = list_of_each_line[t_idx].replace(u'\ufeff', '')
#         expected_answer_list.append(list_of_each_line)
# print("Expected answers = ", expected_answer_list)
# Out:
# Questions =  [['Q1', 'ปัจจุบันประเทศไทยยังเหลือหมาในอยู่ที่ใดบ้าง'], ['Q2', 'หางของแพนด้ายักษ์มีความยาวประมาณเท่าไหร่'], ['Q3', 'งูที่ยาวที่สุดของโลกยาวกี่เมตร'], ['Q4', 'พระพุทธชินราชประดิษฐานอยู่ที่ไหน'], ['Q5', 'ข้าวหอมมะลิมีราคาตันละเท่าไหร่'], ['Q6', 'ใครเป็นผู้จ้างนายสับ วาปีมารับผิดแทน'], ['Q7', 'ลูกแพนด้ายักษ์ที่เพิ่งเกิดจะมีน้ำหนักน้อยกว่าตัวเต็มวัยกี่เท่า'], ['Q8', 'ในปี 2013 โรคเบาหวานเป็นสาเหตุการตายลำดับที่เท่าไหร่'], ['Q9', 'วันที่ 11 พฤศจิกายนที่ผ่านมา วงบอย สเก๊าท์ มีคอนเสิร์ตที่ร้านใดในย่านทาวน์อินทาวน์'], ['Q10', 'คำพื้นฐานที่จำเป็นต่อการเรียนรู้ของชั้นประถมศึกษาปีที่ 2 มีจำนวนกี่คำ'], ['Q11', 'นาวาโท ชัยยุทธ ถูกยิงด้วยอาวุธปืนรวมทั้งสิ้นกี่นัด'], ['Q12', 'ใครถูกรางวัลสลากออมสิน 10,000 บาท'], ['Q13', 'ชูใจเป็นเพื่อนสนิทของใคร'], ['Q14', 'ใครเป็นเจ้าของฟาร์มกุ้งก้ามแดง เอส ล็อบสเตอร์ ฟาร์ม'], ['Q15', 'เทศกาลบอลลูนนานาชาติที่สิงห์ปาร์คมีบอลลูนจากกี่ประเทศมาร่วมโชว์'], ['Q16', 'ใครเป็นผู้ต้องหาที่หลบหนีจากการก่อเหตุยิง นาวาโท ชัยยุทธ'], ['Q17', 'ใครเป็นผู้ใต้บังคับบัญช
# ...

# %%
document_data = []

count_doc = 1
for document in document_list:
    # paragraph_struct = {
    #     'original': '',
    #     'tokenized': '',
    #     'tagged': ''
    # }
    for paragraph in document:
        normalized_paragraph = " ".join(paragraph.split())
        normalized_paragraph = normalized_paragraph.replace('"', '')
        tokenized_paragraph = word_tokenize(text=normalized_paragraph, engine='deepcut')
        tokenized_paragraph = [x for x in tokenized_paragraph if x != ' ']
        for t_idx, token in enumerate(tokenized_paragraph):
            tokenized_paragraph[t_idx] = tokenized_paragraph[t_idx].replace(u'\ufeff', '')
            if ('พล.อ' in tokenized_paragraph[t_idx]):
                tokenized_paragraph[t_idx] = tokenized_paragraph[t_idx].replace('พล.อ ', 'พล.อ.')
                tokenized_paragraph[t_idx] = tokenized_paragraph[t_idx].replace('พล.อป', 'พล.อ.ป')
                tokenized_paragraph[t_idx] = tokenized_paragraph[t_idx].replace('พล.อ ป', 'พล.อ.ป')
                tokenized_paragraph[t_idx] = tokenized_paragraph[t_idx].replace('พล.อ. ', 'พล.อ.')
        # try:
        #     tagged_paragraph = pos_tag(tokenized_paragraph, engine='artagger')
        # except:
        #     pass
        # document_data.append(tagged_paragraph)
        # filtered_words = [word for word in tokenized_paragraph if word not in stopwords]
        # document_data.append(filtered_words)
        document_data.append(tokenized_paragraph)
        print(tokenized_paragraph)
    count_doc = count_doc + 1
    # if count_doc > 28:
    #     break
print(document_data)
# Out:
# ['งูเหลือม', '(', 'อังกฤษ', ':', 'Reticulated', 'python', ';', 'ชื่อ', 'วิทยาศาสตร์', ':', 'Python', 'reticulatus', ')', 'จัด', 'อยู่', 'ใน', 'ไฟลัม', 'สัตว์', 'มี', 'แกน', 'สัน', 'หลัง', 'ชั้น', 'สัตว์', 'เลื้อยคลาน', 'เป็น', 'งู', 'ขนาด', 'ใหญ่', 'ลำ', 'ตัว', 'ยาว', 'เฉลี่ย', 'ประมาณ', '3', '.', '5', '-', '6', 'เมตร', 'จัด', 'เป็น', 'งู', 'ที่', 'ยาว', 'ที่สุด', 'ของ', 'โลก', 'ซึ่ง', 'ตัว', 'ที่', 'ยาว', 'ที่สุด', 'ยาว', 'ถึง', '9', '.', '6', 'เมตร', 'ถูก', 'จับ', 'ได้', 'เมื่อ', 'ปี', 'ค.ศ.', '1917', 'ที่', 'เกาะซีลิเบท', 'เป็น', 'หมู่', 'เกาะ', 'แห่ง', 'หนึ่ง', 'ใน', 'มาเลเซีย', 'โดย', 'มี', 'ความ', 'ยาว', 'กว่า', 'งูอนาคอนดา', '(', 'Eunectes', 'murinus', ')', 'ที่', 'พบ', 'ใน', 'ทวีปอเมริกา', 'ใต้', 'แต่', 'มี', 'น้ำหนัก', 'น้อย', 'กว่า', 'อาจ', 'จะ', 'หนัก', 'น้อย', 'กว่า', 'งู', 'อนาคอนดา', 'ได้', 'ถึง', 'ครึ่ง', 'เท่า', 'ตัว']
# ...

# %%
numeric_question_keywords = ['กี่', 'เท่าไหร่', 'เท่าใด', 'เท่าไร']
location_question_keywords = ['ที่ใด', 'แห่งใด', 'ที่ไหน', 'บริเวณใด', 'จังหวัดใด']
person_question_keywords = ['คือใคร', 'ใครเป็น', 'ใคร', 'ผู้ใด', 'ชนชาติใด', 'ชื่ออะไร']

numeric_question_time_keywords = ['นาน', 'อายุ', 'เวลา']
numeric_question_money_keywords = ['เงิน', 'ราคา']
numeric_question_quantity_keywords = ['ยาว']

person_clue_keywords = ['โดย']

numeric_time_unit_keywords = ['วัน', 'เดือน', 'ปี', 'ขวบ']
numeric_money_unit_keywords = ['บาท', 'ดอลลาร์']
numeric_quantity_unit_keywords = ['เมตร', 'นิ้ว', 'ฟุต', 'หลา', 'ไมล์']
location_answer_keywords = ['อุทยาน', 'โครงการ', 'โรง', 'จังหวัด', 'อำเภอ', 'ตำบล', 'ประเทศ', 'วัด', 'ทวีป', 'สถานี', 'เขตรักษา', 'พื้นที่', 'สนามบิน', 'ป่า']
location_standalone_keywords = ['เขต']
location_continent_keywords = ['ทวีปอเมริกา', 'ทวีปอเมริกาเหนือ', 'ทวีปอเมริกาใต้', 'ทวีปเอเซีย', 'ทวีปยุโรป', 'ทวีปแอฟริกา', 'ทวีปออสเตรเลีย', 'ทวีปแอนตาร์กติกา', 'ทวีปแอฟโฟร-ยูเรเชีย', 'ทวีปยูเรเชีย', 'โอเชียเนีย']
location_region_keywords = ['ภาคเหนือ', 'ภาคตะวันออกเฉียงเหนือ', 'ภาคกลาง', 'ภาคตะวันออก', 'ภาคตะวันตก', 'ภาคใต้', 'ภาคอีสาน']
location_kingdom_keywords = ['อาณาจักรสุโขทัย', 'อาณาจักรอยุธยา', 'อาณาจักรธนบุรี', 'อาณาจักรรัตนโกสินทร์']
person_answer_keywords = ['นาย', 'นาง', 'สม', 'น.ส.', 'ด.ช.', 'เด็กชาย', 'ด.ญ.', 'เด็กหญิง', 'คุณ']
person_all_rank_keywords = ['หม่อม', 'สมเด็จเจ้า', 'เจ้าพระยา', 'พระยา', 'พระ', 'จมื่น', 'หลวง', 'ขุน', 'หมื่น', 'นาย', 'หมู่', 'พระนาย', 'ออกญา', 'ออกพญา', 'ออกพระ', 'ออกขุน', 'ออกหลวง', 'พญา', 'ท้าว', 'มหาเทวี', 'เทวี']
person_gov_rank_keywords = ['จอมพล', 'จอมพลเรือ', 'จอมพลอากาศ', 'พลเอก', 'พลเรือเอก', 'พลอากาศเอก', 'พลโท', 'พลเรือโท', 'พลอากาศโท', 'พลตรี', 'พลเรือตรี', 'พลอากาศตรี', 'พลจัตวา', 'พลเรือจัตวา', 'พลอากาศจัตวา', 'พันเอก', 'นาวาเอก', 'นาวาอากาศเอก', 'พันโท', 'นาวาโท', 'นาวาอากาศโท', 'พันตรี', 'นาวาตรี', 'นาวาอากาศตรี', 'ร้อยเอก', 'เรือเอก', 'เรืออากาศเอก', 'ร้อยโท', 'เรือโท', 'เรืออากาศโท', 'ร้อยตรี', 'เรือตรี', 'เรืออากาศตรี', 'จ่าสิบเอก', 'พันจ่าเอก', 'พันจ่าอากาศเอก', 'จ่าสิบโท', 'พันจ่าโท', 'พันจ่าอากาศโท', 'จ่าสิบตรี', 'พันจ่าตรี', 'พันจ่าอากาศตรี', 'สิบเอก', 'จ่าเอก', 'จ่าอากาศเอก', 'สิบโท', 'จ่าโท', 'จ่าอากาศโท', 'สิบตรี', 'จ่าตรี', 'จ่าอากาศตรี', 'พลทหาร', 'พล.อ.', 'พล.ท.', 'พล.ต.', 'พล.จ.', 'พ.อ.', 'พ.ท.', 'พ.ต.', 'ร.อ.', 'ร.ท.', 'ร.ต.', 'นนร.', 'จ.ส.อ(พ.).', 'จ.ส.อ.', 'จ.ส.ท.', 'จ.ส.ต.', 'ส.อ.', 'ส.ท.', 'ส.ต.', 'ส.ต.', 'พลฯ', 'พล.ร.อ.', 'พล.ร.ท.', 'พล.ร.ต.', 'พล.ร.จ.', 'น.อ.', 'น.ท.', 'น.ต.', 'ร.อ.', 'ร.ท.', 'ร.ต.', 'พ.จ.อ.(พ.)', 'พ.จ.อ.', 'พ.จ.ท.', 'พ.จ.ต.', 'จ.อ.', 'จ.ท.', 'จ.ต.', 'ล.อ.อ.', 'พล.อ.ท.', 'พล.อ.ต.', 'พล.อ.จ.', 'น.อ.', 'น.ท.', 'น.ต.', 'ร.อ.', 'ร.ท.', 'ร.ต.', 'พ.อ.อ.(พ.)', 'พ.อ.อ.', 'พ.อ.ท.', 'พ.อ.ต.', 'จ.อ.', 'จ.ท.', 'จ.ต.', 'พล.ต.อ.', 'พล.ต.ท.', 'พล.ต.ต.', 'พล.ต.จ.', 'พ.ต.อ.', 'พ.ต.ท.', 'พ.ต.ต.', 'ร.ต.อ.', 'ร.ต.ท.', 'ร.ต.ต.', 'นรต.']
person_all_answer_keywords = person_answer_keywords + person_all_rank_keywords + person_gov_rank_keywords
not_location_keywords = numeric_money_unit_keywords + numeric_quantity_unit_keywords + person_all_answer_keywords + ['หมา', 'หมาใน']
not_person_keywords = ['บริษัท', 'จำกัด'] + location_answer_keywords + numeric_money_unit_keywords + numeric_quantity_unit_keywords

KEE_question_index_list = [1, 3, 4, 5, 6, 8]
#select question number here
answer_of_question_list = []
for this_question_index in range(60):
# THIS_QUESTION_INDEX = 10
    this_question = question_list[this_question_index]
#     this_answer = expected_answer_list[this_question_index]
    question_num = this_question[0]
    question_text = this_question[1]

    print(question_text)

    question_type = ''
    question_keyword = ''

    for keyword in numeric_question_keywords:
        if question_text.__contains__(keyword):
            question_type = 'numeric'
            question_keyword = keyword
            break
    if not question_type:
        for keyword in location_question_keywords:
            if question_text.__contains__(keyword):
                question_type = 'location'
                question_keyword = keyword
                break
    if not question_type:
        for keyword in person_question_keywords:
            if question_text.__contains__(keyword):
                question_type = 'person'
                question_keyword = keyword
                break

    tokenized_question_text = word_tokenize(text=question_text, engine='deepcut')
    tokenized_question_text = [x for x in tokenized_question_text if x != ' ']
    # question_text = question_text.replace(question_keyword, '')
    print(tokenized_question_text)
    print(question_type, question_keyword)

#     if question_keyword == 'กี่':
#         unit_keyword = tokenized_question_text[tokenized_question_text.index(question_keyword) + 1]
#         print(question_keyword, unit_keyword)

    found_paragraph_list = []
    for paragraph in document_data:
        # print(paragraph)
        for question_word in tokenized_question_text:
            matching = [s for s in paragraph if question_word in s]
            if matching:
                found_paragraph_list.append(paragraph)
                # print(matching)

    unique_found_paragraph = [list(x) for x in set(tuple(x) for x in found_paragraph_list)]

    filtered_tokenized_question_text = [word for word in tokenized_question_text if word not in thai_stopwords]
    not_thai_word_paragraph_list = []

    co_occur = [[0 for x in range(len(tokenized_question_text))] for y in range(len(unique_found_paragraph))] 
    for p_idx, para in enumerate(unique_found_paragraph):
        for p_word in para:
            for q_idx, q_word in enumerate(tokenized_question_text):
                if q_word == p_word:
    #                 print('[{}][{}] {} {}'.format(p_idx, q_idx, q_word, p_word))
                    if co_occur[p_idx][q_idx] == 0:
                        co_occur[p_idx][q_idx] = 1
                        for loc_keyword in location_answer_keywords:
                            if (q_word.startswith(loc_keyword)) and (loc_keyword != q_word):
    #                             print("q_word", q_word, '=>', p_idx)
                                co_occur[p_idx][q_idx] = 4
                                break
                        for per_keyword in person_all_answer_keywords:
                            if (q_word.startswith(per_keyword)) and (p_word == q_word):
                                co_occur[p_idx][q_idx] = 4
                                break
                if isthai(q_word,check_all=False)['thai'] == 0.0 and not any(i.isdigit() for i in q_word):
                    if q_word == p_word:
                        not_thai_word_paragraph_list.append(para)

    # print(co_occur[52], '->', unique_found_paragraph[52])
    print("Q", tokenized_question_text, "\n---------------------------------------------------------------")
    sum_co_occur = []
    for c_idx, c1 in enumerate(co_occur):
        sum_co_occur.append(sum(c1))
    #     print(c1, '=', sum(c1)) #unique_found_paragraph[c_idx]

    top_co_occur_idx = sorted(range(len(sum_co_occur)), key=lambda i: sum_co_occur[i])[-5:]
    print(top_co_occur_idx)
    for idx in top_co_occur_idx:
        print(sum_co_occur[idx], "->", unique_found_paragraph[idx])
        print(co_occur[idx])
        print('====================================================================')
    # max_co_occur_idx = sum_co_occur.index(max(sum_co_occur))
    # print(sum_co_occur[max_co_occur_idx], "->", unique_found_paragraph[max_co_occur_idx])
    print(not_thai_word_paragraph_list)

    print(tokenized_question_text)

    def check_score(word, word_idx, question, paragraph):
        score = []
        for q_idx, q_word in enumerate(question):
            q_word_dist = [100]
            match_indices = [i for i, x in enumerate(paragraph) if x == q_word]
            for match_idx in match_indices:
                if paragraph[match_idx] == q_word:
                    if paragraph[match_idx] in paragraph and q_word in paragraph:
                        q_word_dist.append((q_idx+1) * abs(match_idx - word_idx))
    #                 print(paragraph[match_idx], q_word_dist[-1])
    #             print(q_word, "q_word_dist", q_word_dist)
            min_dist = min(q_word_dist)
    #         print(q_word, '=>', min_dist)
            score.append(min_dist)
    #     print(paragraph)
    #     print("==================")
        return sum(score) / len(question)

    # print(top_co_occur_idx)

    def unique_list(seq):
        seen = set()
        seen_add = seen.add
        return [x for x in seq if not (x in seen or seen_add(x))]

    print(question_num, tokenized_question_text, "\n---------------------------------------------------------------")
    answer_choice_list = []
    if question_keyword == 'กี่':
        for idx in top_co_occur_idx:
            focused_paragraph = unique_found_paragraph[idx]
            
            first_keyword = tokenized_question_text[tokenized_question_text.index(tokenized_question_text[0])]
            try:
                tq_idx = tokenized_question_text.index(question_keyword)
            except ValueError:
                tq_idx = -1
            last_keyword = tokenized_question_text[tq_idx - 1]
            unit_keyword = tokenized_question_text[tq_idx + 1]
            print(first_keyword, " -> ", last_keyword, question_keyword, unit_keyword)
    #         print("first_idx", tokenized_question_text.index(tokenized_question_text[0]))
    #         print("last_idx", tokenized_question_text.index(question_keyword) - 1)
    #         print("unit_idx", tokenized_question_text.index(question_keyword) + 1)
            try:    
                first_idx = focused_paragraph.index(first_keyword)
            except ValueError:
                first_idx = -1
            try:
                last_idx = focused_paragraph.index(last_keyword) + 1
            except ValueError:
                last_idx = -1
            try:
                last_idx = focused_paragraph.index(tokenized_question_text[tokenized_question_text.index(question_keyword) - 2]) + 0
            except ValueError:
                last_idx = -1
            try:
                unit_idx = focused_paragraph.index(unit_keyword)
                normal_flow = True
            except ValueError:
                normal_flow = False
            if (normal_flow):
                print(focused_paragraph[first_idx:last_idx+2])
                direct_answer = focused_paragraph[last_idx:unit_idx+1]
                number_in_direct_answer = re.findall(r'\b\d+\b', ' '.join(direct_answer))
                if number_in_direct_answer:
                    actual_direct_unit = focused_paragraph[focused_paragraph.index(number_in_direct_answer[0]) + 1]
                    if actual_direct_unit == unit_keyword:
                        print(number_in_direct_answer[0], actual_direct_unit)
                        main_answer = number_in_direct_answer[0]
                        main_answer_index = focused_paragraph.index(main_answer)
                        answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                        answer_plain_text = '{} {}'.format(number_in_direct_answer[0], unit_keyword)
                        answer_dict = {'answer': answer_plain_text, 'score': answer_score}
                        answer_choice_list.append(answer_dict)
                unit_indices = [i for i, x in enumerate(focused_paragraph) if x == unit_keyword]
                next_first_idx = first_idx
                print("-----------------------------------")
                for u_idx in unit_indices:
                    cut_paragraph = focused_paragraph[next_first_idx:u_idx+1]
                    number_in_cut_paragraph = re.findall(r'\b\d+\b', ' '.join(cut_paragraph))
                    for number_text in number_in_cut_paragraph:
                        if (number_text in cut_paragraph):
                            num_idx  = cut_paragraph.index(number_text)
                            answer_number = cut_paragraph[num_idx]
                            answer_unit = cut_paragraph[num_idx+1]
                            print("@", answer_number, answer_unit)
                            if answer_unit == "-":
                                answer_number_text = ''.join(cut_paragraph[num_idx:num_idx+3])
                                answer_unit = cut_paragraph[num_idx+3]
                                if answer_unit == unit_keyword:
                                    main_answer = answer_number
                                    main_answer_index = focused_paragraph.index(main_answer)
                                    answer_plain_text = '{} {}'.format(answer_number_text, answer_unit)
                                    answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                                    answer_dict = {'answer': answer_plain_text, 'score': answer_score}
                                    answer_choice_list.append(answer_dict)
                                    print("answer_plain_text", answer_plain_text)
                            elif answer_unit == unit_keyword:
                                if all(i.isdigit() for i in answer_unit):
                                    if float(answer_unit) != 0:
                                        main_answer = answer_number
                                        main_answer_index = focused_paragraph.index(main_answer)
                                        answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                                        answer_plain_text = '{} {}'.format(answer_number, answer_unit)
                                        answer_dict = {'answer': answer_plain_text, 'score': answer_score}
                                        answer_choice_list.append(answer_dict)
                                        print('&', answer_number, answer_unit)
                                        print("answer_choice_list", answer_choice_list)
                                        print("------------------------------------------")
                                else:
                                    if all(i.isdigit() for i in answer_number):
                                        if float(answer_number) != 0:
                                            main_answer = answer_number
                                            main_answer_index = focused_paragraph.index(main_answer)
                                            answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                                            answer_plain_text = '{} {}'.format(answer_number, answer_unit)
                                            answer_dict = {'answer': answer_plain_text, 'score': answer_score}
                                            answer_choice_list.append(answer_dict)
                                            print('^', answer_number, answer_unit)
                                            print("answer_choice_list", answer_choice_list)
                                            print("------------------------------------------")
                    print(cut_paragraph, '=>', number_in_cut_paragraph)
                    next_first_idx = u_idx+1
            if (not normal_flow or not answer_choice_list):
                for para_eng in not_thai_word_paragraph_list:
                    unit_indices = [i for i, x in enumerate(para_eng) if x == unit_keyword]
                    for u_idx in unit_indices:
                        direct_answer_number = para_eng[u_idx-1]
                        direct_answer_unit = para_eng[u_idx]
                        if any(i == '-' for i in direct_answer_number):
                            direct_answer_number = para_eng[u_idx-1:u_idx+3]
                            direct_answer_unit = para_eng[u_idx+3]
                        if all(i.isdigit() for i in direct_answer_number):
                            main_answer = para_eng[u_idx-1]
                            main_answer_index = para_eng.index(main_answer)
                            answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, para_eng)
                            answer_plain_text = '{} {}'.format(direct_answer_number, direct_answer_unit)
                            answer_dict = {'answer': answer_plain_text, 'score': answer_score}
                            answer_choice_list.append(answer_dict)
                            print("direct_answer_number, direct_answer_unit", direct_answer_number, direct_answer_unit)
            print("===================================")
    elif question_type == 'numeric' and question_keyword != 'กี่':
        numeric_unit_list = []
        for keyword in numeric_question_time_keywords:
            if question_text.__contains__(keyword):
                numeric_unit_list = numeric_time_unit_keywords
                break
        if not numeric_unit_list:
            for keyword in numeric_question_money_keywords:
                if question_text.__contains__(keyword):
                    numeric_unit_list = numeric_money_unit_keywords
                    break
        if not numeric_unit_list:
            for keyword in numeric_question_quantity_keywords:
                if question_text.__contains__(keyword):
                    numeric_unit_list = numeric_quantity_unit_keywords
                    break
        for idx in top_co_occur_idx:
            focused_paragraph = unique_found_paragraph[idx]
            number_in_focused_paragraph = re.findall(r'\b\d+\b', ' '.join(focused_paragraph))
            print("number_in_focused_paragraph", number_in_focused_paragraph)
            for number_text in number_in_focused_paragraph:
                number_idx = focused_paragraph.index(number_text)
                unit_idx = number_idx + 1
                number_text = focused_paragraph[number_idx]
                unit_text = focused_paragraph[unit_idx]
                print(number_text, unit_text)
                if numeric_unit_list == numeric_money_unit_keywords:
                    if unit_text == ',':
                        next_number_text = focused_paragraph[unit_idx+1]
                        if all(i.isdigit() for i in next_number_text):
                            main_answer = number_text
                            main_answer_index = focused_paragraph.index(main_answer)
                            number_text = ''.join(focused_paragraph[number_idx:number_idx+3])
                            unit_text = focused_paragraph[number_idx+3]
                            print("$", number_text, unit_text)
                            answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                            answer_plain_text = '{} {}'.format(number_text, unit_text)
                            answer_dict = {'answer': answer_plain_text, 'score': answer_score}
                            answer_choice_list.append(answer_dict)
    #             elif (not answer_choice_list) or (unit_text in numeric_unit_list):
                else:
    #                 print(number_text, unit_text, "in")
                    check_exist_in_unit_list = []
                    for u_word in numeric_unit_list:
                        if u_word in unit_text:
                            check_exist_in_unit_list.append(u_word)
                            break
                    if check_exist_in_unit_list:
                        print(unit_text, "in?", numeric_unit_list)
                        if (float(number_text) != 0) and (check_exist_in_unit_list):
                            main_answer = number_text
                            main_answer_index = focused_paragraph.index(main_answer)
                            answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                            answer_plain_text = '{} {}'.format(number_text, unit_text)
                            answer_dict = {'answer': answer_plain_text, 'score': answer_score}
                            answer_choice_list.append(answer_dict)
#                             print(keyword, '=>', candidate_answer_text)
            #                 print(number_in_focused_paragraph)
            print("===================================")
    elif question_type == 'person':
        for idx in top_co_occur_idx:
            focused_paragraph = unique_found_paragraph[idx]
            for p_idx, p_word in enumerate(focused_paragraph):
                person_pass = True
                for n_keyword in not_person_keywords:
                    if n_keyword in p_word:
                        person_pass = False
                if person_pass:
                    r = re.compile(u'.*ฯ.*')
                    # Firstname Lastname
                    if (r.match(p_word) is None):
                        r = re.compile(u'[ก-๙].+ [ก-๙].+')
                        # check from regex 'Firstname Lastname'
                        if (r.match(p_word) is not None) and (not any(i.isdigit() for i in p_word)):
                            p_word_test_thai = p_word.replace('.', '')
                            p_word_test_thai = p_word_test_thai.replace(' ', '')
                            # do not consider any puntuation marks
                            if (isthai(p_word_test_thai,check_all=True)['thai'] == 100.0):
                                if (p_word not in tokenized_question_text):
                                    main_answer = p_word
                                    main_answer_index = focused_paragraph.index(main_answer)
                                    answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                                    answer_dict = {'answer': main_answer, 'score': answer_score}
                                    answer_choice_list.append(answer_dict)
                                    print(p_word, "is matched")
                        # check from provided list (likely to be person name), i.e., gov rank
                        for person_keyword in person_all_answer_keywords:
                            if (p_word.startswith(person_keyword)) and (person_keyword != p_word):
                                answer_word = focused_paragraph[p_idx:p_idx+2]
                                answer_word_test_thai = ''.join(answer_word).replace('.', '')
                                answer_word_test_thai = answer_word_test_thai.replace(' ', '')
                                # do not consider any puntuation marks
                                if (isthai(''.join(answer_word_test_thai),check_all=True)['thai'] == 100.0):
                                    if (answer_word not in tokenized_question_text):
                                        main_answer = p_word
                                        main_answer_index = focused_paragraph.index(main_answer)
                                        answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                                        answer_dict = {'answer': ' '.join(answer_word), 'score': answer_score}
                                        answer_choice_list.append(answer_dict)
                                        print(answer_word, "is matched with keyword", person_keyword)
                                        break
    #     top_paragraph = unique_found_paragraph[top_co_occur_idx[4]]
            top_paragraph = focused_paragraph
            doay_keyword_indices = [i for i, x in enumerate(top_paragraph) if x == 'โดย']
            for doay_idx in doay_keyword_indices:
                contiguous_noun_list = []
                current_noun_idx = doay_idx + 1
                noun_after_doay = top_paragraph[min(current_noun_idx, len(top_paragraph))]
                noun_after_doay_pos_tag = pos_tag([noun_after_doay],engine='artagger')
                noun_after_doay_pos_tag_text = noun_after_doay_pos_tag[0][1]
                print("noun_after_doay_pos_tag", noun_after_doay_pos_tag)
                print("noun_after_doay", noun_after_doay)
                current_noun_idx = min(current_noun_idx + 1, len(top_paragraph)-1)
                if (noun_after_doay_pos_tag_text == 'NCMN'):
                    if current_noun_idx == len(top_paragraph)-1:
                        break
                    contiguous_noun_list.append(noun_after_doay)
                    noun_after_doay = top_paragraph[current_noun_idx]
                    noun_after_doay_pos_tag = pos_tag([noun_after_doay],engine='artagger')
                    noun_after_doay_pos_tag_text = noun_after_doay_pos_tag[0][1]
                    print("noun_after_doay_pos_tag", noun_after_doay_pos_tag)
                    print("noun_after_doay", noun_after_doay)
                    current_noun_idx = min(current_noun_idx + 1, len(top_paragraph)-1)
                print("contiguous_noun_list", contiguous_noun_list)
                contiguous_noun_text = ' '.join(contiguous_noun_list)
                print("contiguous_noun_text", contiguous_noun_text)
                if contiguous_noun_list:
                    location_pass = True
                    for n_keyword in not_person_keywords:
                        if n_keyword in p_word:
                            location_pass = False
                            break
                    for per_keyword in person_all_answer_keywords:
                        if (contiguous_noun_text == per_keyword):
                            location_pass = False
                            break
                    same_as_in_question = False
                    for q_word in tokenized_question_text:
                        if (contiguous_noun_text == q_word):
        #                     print(p_word, q_word, 'break')
                            same_as_in_question = True
                            break
                    if same_as_in_question:
                        break
                    if location_pass:
                        main_answer = contiguous_noun_list[0]
                        main_answer_index = focused_paragraph.index(main_answer)
                        answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                        answer_dict = {'answer': contiguous_noun_text, 'score': answer_score}
                        answer_choice_list.append(answer_dict)
    elif question_type == 'location':
        for q_word in tokenized_question_text:
            if 'ใด' in q_word:
                dai_index = tokenized_question_text.index(q_word)
        possible_keywords = ''
        if (dai_index):
            for q_idx, q_word in enumerate(tokenized_question_text):
                if ('ทวีป' in q_word):
                    if (q_idx <= dai_index) and (abs(q_idx - dai_index) <= 2):
                        possible_keywords = location_continent_keywords
                elif ('ภาค' in q_word) :
                    if (q_idx <= dai_index) and (abs(q_idx - dai_index) <= 2):
                        possible_keywords = location_region_keywords
                elif ('อาณาจักร' in q_word):
                    if (q_idx <= dai_index) and (abs(q_idx - dai_index) <= 2):
                        possible_keywords = location_kingdom_keywords
                elif ('ประเทศ' in q_word):
                    if (q_idx <= dai_index) and (abs(q_idx - dai_index) <= 2):
                        possible_keywords = 'ประเทศ'
        for idx in top_co_occur_idx:
            focused_paragraph = unique_found_paragraph[idx]
            province_only = False
            for q_word in tokenized_question_text:
                if ('จังหวัด' in q_word):
                    province_only = True
            for p_idx, p_word in enumerate(focused_paragraph):
                for q_idx, q_word in enumerate(tokenized_question_text):
                    if (q_word == p_word):
                        continue
                    location_pass = True
                    for n_keyword in not_location_keywords:
                        if n_keyword in p_word:
                            location_pass = False
                            break
                    if location_pass:
                        for loc_keyword in location_answer_keywords:
                            if (p_word.startswith(loc_keyword)) and (loc_keyword != p_word):
    #                             print("p_word", p_word)
                                if (province_only) and ('จังหวัด' not in p_word):
                                    break
                                if possible_keywords != '':
                                    if ((possible_keywords == location_continent_keywords and p_word not in possible_keywords)
                                    or (possible_keywords == location_region_keywords and p_word not in possible_keywords)
                                    or (possible_keywords == location_kingdom_keywords and p_word not in possible_keywords)):
                                        break
                                same_as_in_question = False
                                for q_word in tokenized_question_text:
                                    if (p_word == q_word):
    #                                     print(p_word, q_word, 'break')
                                        same_as_in_question = True
                                        break
                                if same_as_in_question:
                                    break
                                if (p_word.startswith('ทวีป')):
                                    loc_key_pass = False
                                    for l_keyword in location_continent_keywords:
                                        if p_word == l_keyword:
                                            loc_key_pass = True
                                    if not loc_key_pass:
                                        break
                                if (p_word.startswith('ภาค')):
                                    loc_key_pass = False
                                    for l_keyword in location_region_keywords:
                                        if p_word == l_keyword:
                                            loc_key_pass = True
                                    if not loc_key_pass:
                                        break
                                if (p_word.startswith('อาณาจักร')):
                                    loc_key_pass = False
                                    for l_keyword in location_kingdom_keywords:
                                        if p_word == l_keyword:
                                            loc_key_pass = True
                                    if not loc_key_pass:
                                        break
                                main_answer = p_word
                                main_answer_index = focused_paragraph.index(main_answer)
                                answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
    #                             if (co_occur[p_idx][q_idx] > 1):
    #                                 answer_score = answer_score / (co_occur[p_idx][q_idx] - 1)
                                answer_dict = {'answer': main_answer, 'score': answer_score}
                                answer_choice_list.append(answer_dict)
                                print(p_word)
    #                                 print(l_idx, p_word, "in location_answer_keywords", loc_keyword)
                                break
        top_paragraph = unique_found_paragraph[top_co_occur_idx[4]]

        nai_keyword_indices = [i for i, x in enumerate(top_paragraph) if x == 'ใน']
        for nai_idx in nai_keyword_indices:
            contiguous_noun_list = []
            current_noun_idx = nai_idx
            noun_after_nai = top_paragraph[current_noun_idx]
            noun_after_nai_pos_tag = pos_tag([noun_after_nai],engine='artagger')
            noun_after_nai_pos_tag_text = noun_after_nai_pos_tag[0][1]
            print("noun_after_nai_pos_tag", noun_after_nai_pos_tag)
            print("noun_after_nai", noun_after_nai)
            current_noun_idx = min(current_noun_idx + 1, len(top_paragraph)-1)
            while (noun_after_nai_pos_tag_text == 'NCMN'):
                contiguous_noun_list.append(noun_after_nai)
                noun_after_nai = top_paragraph[current_noun_idx]
                noun_after_nai_pos_tag = pos_tag([noun_after_nai],engine='artagger')
                noun_after_nai_pos_tag_text = noun_after_nai_pos_tag[0][1]
                print("noun_after_nai_pos_tag", noun_after_nai_pos_tag)
                print("noun_after_nai", noun_after_nai)
                current_noun_idx = min(current_noun_idx + 1, len(top_paragraph)-1)
            print("contiguous_noun_list", contiguous_noun_list)
            contiguous_noun_text = ''.join(contiguous_noun_list)
            print("contiguous_noun_text", contiguous_noun_text)
            if contiguous_noun_list:
                location_pass = True
                for n_keyword in not_location_keywords:
                    if n_keyword in p_word:
                        location_pass = False
                        break
                if (p_word == 'หมา'):
                        print(p_word, '=>', location_pass)
                for loc_keyword in location_answer_keywords:
                    if (contiguous_noun_text == loc_keyword):
                        location_pass = False
                        break
                for loc_keyword in location_standalone_keywords:
                    if (contiguous_noun_text == loc_keyword):
                        location_pass = False
                        break
                same_as_in_question = False
                for q_word in tokenized_question_text:
                    if (contiguous_noun_text == q_word):
    #                     print(p_word, q_word, 'break')
                        same_as_in_question = True
                        break
                if same_as_in_question:
                    break
                if (contiguous_noun_text.startswith('ทวีป')):
                    loc_key_pass = False
                    for l_keyword in location_continent_keywords:
                        if contiguous_noun_text == l_keyword:
                            loc_key_pass = True
                    if not loc_key_pass:
                        break
                if (contiguous_noun_text.startswith('ภาค')):
                    loc_key_pass = False
                    for l_keyword in location_region_keywords:
                        if contiguous_noun_text == l_keyword:
                            loc_key_pass = True
                    if not loc_key_pass:
                        break
                if (contiguous_noun_text.startswith('อาณาจักร')):
                    loc_key_pass = False
                    for l_keyword in location_kingdom_keywords:
                        if contiguous_noun_text == l_keyword:
                            loc_key_pass = True
                    if not loc_key_pass:
                        break
                if location_pass:
                    main_answer = contiguous_noun_list[0]
                    main_answer_index = focused_paragraph.index(main_answer)
                    answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                    answer_dict = {'answer': contiguous_noun_text, 'score': answer_score}
                    answer_choice_list.append(answer_dict)
        tee_keyword_indices = [i for i, x in enumerate(top_paragraph) if x == 'ที่']
        for tee_idx in tee_keyword_indices:
            contiguous_noun_list = []
            current_noun_idx = tee_idx + 1
            noun_after_tee = top_paragraph[min(current_noun_idx, len(top_paragraph))]
            noun_after_tee_pos_tag = pos_tag([noun_after_tee],engine='artagger')
            noun_after_tee_pos_tag_text = noun_after_tee_pos_tag[0][1]
            print("noun_after_tee_pos_tag", noun_after_tee_pos_tag)
            print("noun_after_tee", noun_after_tee)
            current_noun_idx = min(current_noun_idx + 1, len(top_paragraph)-1)
            while (noun_after_tee_pos_tag_text == 'NCMN'):
                if current_noun_idx == len(top_paragraph)-1:
                    break
                contiguous_noun_list.append(noun_after_tee)
                noun_after_tee = top_paragraph[current_noun_idx]
                noun_after_tee_pos_tag = pos_tag([noun_after_tee],engine='artagger')
                noun_after_tee_pos_tag_text = noun_after_tee_pos_tag[0][1]
                print("noun_after_tee_pos_tag", noun_after_tee_pos_tag)
                print("noun_after_tee", noun_after_tee)
                current_noun_idx = min(current_noun_idx + 1, len(top_paragraph)-1)
            print("contiguous_noun_list", contiguous_noun_list)
            contiguous_noun_text = ''.join(contiguous_noun_list)
            print("contiguous_noun_text", contiguous_noun_text)
            if contiguous_noun_list:
                location_pass = True
                for n_keyword in not_location_keywords:
                    if n_keyword in p_word:
                        location_pass = False
                        break
                if (p_word == 'หมา'):
                        print(p_word, '=>', location_pass)
                for loc_keyword in location_answer_keywords:
                    if (contiguous_noun_text == loc_keyword):
                        location_pass = False
                        break
                for loc_keyword in location_standalone_keywords:
                    if (contiguous_noun_text == loc_keyword):
                        location_pass = False
                        break
                same_as_in_question = False
                for q_word in tokenized_question_text:
                    if (contiguous_noun_text == q_word):
    #                     print(p_word, q_word, 'break')
                        same_as_in_question = True
                        break
                if same_as_in_question:
                    break
                if (contiguous_noun_text.startswith('ทวีป')):
                    loc_key_pass = False
                    for l_keyword in location_continent_keywords:
                        if contiguous_noun_text == l_keyword:
                            loc_key_pass = True
                    if not loc_key_pass:
                        break
                if (contiguous_noun_text.startswith('ภาค')):
                    loc_key_pass = False
                    for l_keyword in location_region_keywords:
                        if contiguous_noun_text == l_keyword:
                            loc_key_pass = True
                    if not loc_key_pass:
                        break
                if (contiguous_noun_text.startswith('อาณาจักร')):
                    loc_key_pass = False
                    for l_keyword in location_kingdom_keywords:
                        if contiguous_noun_text == l_keyword:
                            loc_key_pass = True
                    if not loc_key_pass:
                        break
                if location_pass:
                    main_answer = contiguous_noun_list[0]
                    main_answer_index = focused_paragraph.index(main_answer)
                    answer_score = check_score(main_answer, main_answer_index, tokenized_question_text, focused_paragraph)
                    answer_dict = {'answer': contiguous_noun_text, 'score': answer_score}
                    answer_choice_list.append(answer_dict)

    answer_string = '{}::'.format(question_num)
    sorted_answer_choice_list = sorted(answer_choice_list, key=lambda k: k['score']) 
    print(sorted_answer_choice_list)
    print("--------------------------------------------------------")
    candidate_answer_list = []
    for idx, ans in enumerate(sorted_answer_choice_list):
        normalized_ans = re.sub(' +',' ', ans['answer'])
        candidate_answer_list.append(normalized_ans)
    candidate_answer_list = unique_list(candidate_answer_list)
    for idx, ans in enumerate(candidate_answer_list):
        if idx == 5:
            break
        answer_string = answer_string + ans + '||'
    answer_string = answer_string[:-2]
    print(answer_string)
#     print("Solution =", this_answer[1])
    answer_of_question_list.append(answer_string)
# Out:
# ปัจจุบันประเทศไทยยังเหลือหมาในอยู่ที่ใดบ้าง
# ['ปัจจุบัน', 'ประเทศไทย', 'ยัง', 'เหลือหมา', 'ใน', 'อยู่', 'ที่', 'ใด', 'บ้าง']
# location ที่ใด
# Q ['ปัจจุบัน', 'ประเทศไทย', 'ยัง', 'เหลือหมา', 'ใน', 'อยู่', 'ที่', 'ใด', 'บ้าง']
# ---------------------------------------------------------------
# [237, 240, 248, 297, 379]
# ...

# %%
with open('570610601-test1.txt', 'w', encoding='utf-8') as file:
    for q_ans in answer_of_question_list:
        file.write(q_ans + '\n')
print("Write answer of all questions to file .. done")
# Out:
# Write answer of all questions to file .. done
